# %%
# Comparison operators

# %%
2 == 2
# Out:
# True

# %%
2 == 1
# Out:
# False

# %%
'bye' == 'bye'
# Out:
# True

# %%
2.0 == 2
# Out:
# True

# %%
3 != 3
# Out:
# False

# %%
4 != 5
# Out:
# True

# %%
2 > 1
# Out:
# True

# %%
1 > 2
# Out:
# False

# %%
1 < 5
# Out:
# True

# %%
2 >= 3
# Out:
# False

# %%
5 <= 1
# Out:
# False

# %%
# Chaining Comparison Operators in Python with Logical Operators

# %%
1 < 2 < 3
# Out:
# True

# %%
1 < 2 > 3
# Out:
# False

# %%
1 < 2 and 2 > 3
# Out:
# False

# %%
'h' == 'h' and 2 == 2
# Out:
# True

# %%
('h' == 'h') and (2 == 2)
# Out:
# True

# %%
('h' == 'k') or (2 == 2)
# Out:
# True

# %%
not(1 == 1)
# Out:
# False

# %%
not 1 == 1
# Out:
# False

# %%
not 400 > 5000
# Out:
# True
