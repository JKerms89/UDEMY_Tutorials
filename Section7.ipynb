# %%
#Displaying information

def display(row1,row2,row3):
  print(row1)
  print(row2)
  print(row3)

example_row = [1,2,3]

display(example_row, example_row, example_row)
# Out:
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]

# %%
row1 = [' ', ' ', ' ']
row2 = [' ', ' ', ' ']
row3 = [' ', ' ', ' ']

# %%
display(row1,row2,row3)
# Out:
# [' ', ' ', ' ']
# [' ', ' ', ' ']
# [' ', ' ', ' ']

# %%
row2[1] = 'X'

# %%
display(row1,row2,row3)
# Out:
# [' ', ' ', ' ']
# [' ', 'X', ' ']
# [' ', ' ', ' ']

# %%
# Accepting user input

# %%
input("Please enter a value: ")
# Out:
# Please enter a value: 2
# '2'

# %%
result = input("Please enter a value: ")
# Out:
# Please enter a value: 2

# %%
result
# Out:
# '2'

# %%
type(result)
# Out:
# str

# %%
result = input("Please enter a value: ")
# Out:
# Please enter a value: 2

# %%
result_int = int(result)

# %%
type(result_int)
# Out:
# int

# %%
float('3.41')
# Out:
# 3.41

# %%
position_index = input("Choose an index position: ")
# Out:
# Choose an index position: 1

# %%
position_index = int(input("Choose an index position: "))
# Out:
# Choose an index position: 1

# %%
row2[position_index]
# Out:
# 'X'

# %%
result = input("Enter a number: ")
# Out:
# Enter a number: 2

# %%
2+2
# Out:
# 4

# %%
def user_choice():

  choice = 'WRONG'

  while choice.isdigit() == False:
    
    choice = input("Please enter a number (0-10): ")

    if choice.isdigit() == False:
      print("Sorry that is not a digit!")
  
  if choice.isdigit() == True:
    choice = int(choice)
    if choice >= 0 and choice <= 10:
      return choice
    else:
      print('This number is not in range!')

user_choice()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     726         """
# --> 727         parts = [self.recv(flags, copy=copy, track=track)]
#     728         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-ef1da8966f79> in <module>()
#      17       print('This number is not in range!')
#      18
# ---> 19 user_choice()
#
# <ipython-input-33-ef1da8966f79> in user_choice()
#       5   while choice.isdigit() == False:
#       6
# ----> 7     choice = input("Please enter a number (0-10): ")
#       8
#       9     if choice.isdigit() == False:
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
def user_choice():

  #VARIABLES

  choice = 'WRONG'
  acceptable_range = range(0,11)
  within_range = False

  #TWO CONDITIONS TO CHECK
  # DIGIT OR WITHIN_RANGE==FALSE
  while choice.isdigit() == False or within_range==False:
    
    choice = input("Please enter a number (0-10): ")

    #DIGIT CHECK
    if choice.isdigit() == False:
      print("Sorry that is not a digit!")

    #RANGE CHECK
    if choice.isdigit() == True:
      if int(choice) in acceptable_range:
        within_range = True
      else:
        print("This number is not in range")
  return int(choice)

user_choice()
# Out:
# Please enter a number (0-10): 11
# This number is not in range
# Please enter a number (0-10): nine
# Sorry that is not a digit!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     726         """
# --> 727         parts = [self.recv(flags, copy=copy, track=track)]
#     728         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-186c6658691a> in <module>()
#      25   return int(choice)
#      26
# ---> 27 user_choice()
#
# <ipython-input-38-186c6658691a> in user_choice()
#      11   while choice.isdigit() == False or within_range==False:
#      12
# ---> 13     choice = input("Please enter a number (0-10): ")
#      14
#      15     #DIGIT CHECK
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
from threading import Timer
import winsound

def twenty_secs():
  global text
  text = "Your 20 seconds are up!"
  print(f"{text}")
  duration = 1000  # milliseconds
  freq = 440  # Hz
  winsound.Beep(freq, duration)
  Timer(20, twenty_secs).start()

twenty_secs()

# %%
# Simple user interaction

# %%
game_list = [0,1,2]

# %%
def display_game(game_list):
  print("Here is the current list: ")
  print(game_list)

# %%
display_game(game_list)
# Out:
# Here is the current list:
# [0, 1, 2]

# %%
def position_choice():

  choice = 'wrong'

  while choice not in ['0','1', '2']:

    choice = input("Pick a position (0,1,2: ")

    if choice not in ['0','1', '2']:
      print("Sorry, invalid choice! ")

  return(int(choice))

# %%
position_choice()
# Out:
# Pick a position (0,1,2: one
# Sorry, invalid choice!
# Pick a position (0,1,2: 3
# Sorry, invalid choice!
# Pick a position (0,1,2: 1
# 1

# %%
def replacement_choice(game_list, position):

  user_placement = input("Type a string to place at position: ")

  game_list[position] = user_placement

  return game_list

replacement_choice(game_list, 1)
# Out:
# Type a string to place at position: Hello
# [0, 'Hello', 2]

# %%
def gameon_choice():

  choice = 'wrong'

  while choice not in ['Y', 'N']:

    choice = input("Keep playing? (Y or N)" ) 

    if choice not in ['Y', 'N']:
      print("Sorry, I don't understand, please choose Y or N")

  if choice == 'Y':
    return True
  else:
    return False

# %%
gameon_choice()
# Out:
# Keep playing? (Y or N)N
# False

# %%
game_on = True
game_list = [0,1,2]

while game_on:

  display_game(game_list)

  position = position_choice()

  game_list = replacement_choice(game_list, position)

  display_game(game_list)

  game_on = gameon_choice()
# Out:
# Here is the current list:
# [0, 1, 2]
# Pick a position (0,1,2: 1
# Type a string to place at position: One
# Here is the current list:
# [0, 'One', 2]
# Keep playing? (Y or N)N
